# %% [markdown]
# ## Indian Start-Up Funding Ecosystem

# %% [markdown]
# ### Loading the datasets

# %%
# Import requisite libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Creating dataframes based on each dataset

data1 = 'startup_funding2018.csv'
data2 = 'startup_funding2019.csv'
data3 = 'startup_funding2020.csv'
data4 = 'startup_funding2021.csv'

df1 = pd.read_csv(data1)
df2 = pd.read_csv(data2)
df3 = pd.read_csv(data3)
df4 = pd.read_csv(data4)

# %%
# Adding a year column to each dataset so that rows are not lost should it become necessary to merge all datasets later on
year_1 = 2018
df1['Year'] = year_1

year_2 = 2019
df2['Year'] = year_2

year_3 = 2020
df3['Year'] = year_3

year_4 = 2021
df4['Year'] = year_4

# Convert the year column from int data type to year data type
df1['Year'] = pd.to_datetime(df1['Year'], format='%Y').dt.year

df2['Year'] = pd.to_datetime(df2['Year'], format='%Y').dt.year

df3['Year'] = pd.to_datetime(df3['Year'], format='%Y').dt.year

df4['Year'] = pd.to_datetime(df4['Year'], format='%Y').dt.year

# %% [markdown]
# ### Data Cleaning

# %%
# Preview of df1
df1.head()
# Out:
#       Company Name                                           Industry  \
# 0  TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1  Happy Cow Dairy                               Agriculture, Farming
# 2       MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3      PayMe India                        Financial Services, FinTech
# 4         Eunimart                 E-Commerce Platforms, Retail, SaaS
#
#   Round/Series       Amount                          Location  \
# 0         Seed       250000       Bangalore, Karnataka, India
# 1         Seed  ₹40,000,000        Mumbai, Maharashtra, India
# 2     Series A  ₹65,000,000           Gurgaon, Haryana, India
# 3        Angel      2000000       Noida, Uttar Pradesh, India
# 4         Seed            —  Hyderabad, Andhra Pradesh, India
#
#                                        About Company  Year
# 0  TheCollegeFever is a hub for fun, fiesta and f...  2018
# 1  A startup which aggregates milk from dairy far...  2018
# 2          Leading Online Loans Marketplace in India  2018
# 3  PayMe India is an innovative FinTech organizat...  2018
# 4  Eunimart is a one stop solution for merchants ...  2018

# %%
# Preview of df2
df2.head()
# Out:
#     Company/Brand  Founded HeadQuarter           Sector  \
# 0  Bombay Shaving      NaN         NaN        Ecommerce
# 1       Ruangguru   2014.0      Mumbai           Edtech
# 2        Eduisfun      NaN      Mumbai           Edtech
# 3        HomeLane   2014.0     Chennai  Interior design
# 4        Nu Genes   2004.0   Telangana         AgriTech
#
#                                         What it does  \
# 0         Provides a range of male grooming products
# 1  A learning platform that provides topic-based ...
# 2            It aims to make learning fun via games.
# 3              Provides interior designing solutions
# 4  It is a seed company engaged in production, pr...
#
#                                 Founders  \
# 0                     Shantanu Deshpande
# 1  Adamas Belva Syah Devara, Iman Usman.
# 2                          Jatin Solanki
# 3           Srikanth Iyer, Rama Harinath
# 4                 Narayana Reddy Punyala
#
#                                             Investor     Amount($)  \
# 0                               Sixth Sense Ventures    $6,300,000
# 1                                   General Atlantic  $150,000,000
# 2     Deepak Parekh, Amitabh Bachchan, Piyush Pandey   $28,000,000
# 3  Evolvence India Fund (EIF), Pidilite Group, FJ...   $30,000,000
# 4           Innovation in Food and Agriculture (IFA)    $6,000,000
#
#            Stage  Year
# 0            NaN  2019
# 1       Series C  2019
# 2  Fresh funding  2019
# 3       Series D  2019
# 4            NaN  2019

# %%
# Preview of df3
df3.head()
# Out:
#   Company_Brand  Founded HeadQuarter              Sector  \
# 0    Aqgromalin   2019.0     Chennai            AgriTech
# 1      Krayonnz   2019.0   Bangalore              EdTech
# 2  PadCare Labs   2018.0        Pune  Hygiene management
# 3         NCOME   2020.0   New Delhi              Escrow
# 4    Gramophone   2016.0      Indore            AgriTech
#
#                                         What_it_does  \
# 0                       Cultivating Ideas for Profit
# 1  An academy-guardian-scholar centric ecosystem ...
# 2   Converting bio-hazardous waste to harmless waste
# 3                       Escrow-as-a-service platform
# 4  Gramophone is an AgTech platform enabling acce...
#
#                                             Founders  \
# 0                    Prasanna Manogaran, Bharani C L
# 1                   Saurabh Dixit, Gurudutt Upadhyay
# 2                                    Ajinkya Dhariya
# 3                                      Ritesh Tiwari
# 4  Ashish Rajan Singh, Harshit Gupta, Nishant Mah...
#
#                               Investor    Amount     Stage column10  Year
# 0                      Angel investors  200000.0       NaN      NaN  2020
# 1                      GSF Accelerator  100000.0  Pre-seed      NaN  2020
# 2                       Venture Center       NaN  Pre-seed      NaN  2020
# 3  Venture Catalysts, PointOne Capital  400000.0       NaN      NaN  2020
# 4  Siana Capital Management, Info Edge  340000.0       NaN      NaN  2020

# %%
# Preview of df4
df4.head()
# Out:
#     Company_Brand  Founded HeadQuarter          Sector  \
# 0  Unbox Robotics   2019.0   Bangalore      AI startup
# 1          upGrad   2015.0      Mumbai          EdTech
# 2     Lead School   2012.0      Mumbai          EdTech
# 3         Bizongo   2015.0      Mumbai  B2B E-commerce
# 4        FypMoney   2021.0    Gurugram         FinTech
#
#                                         What_it_does  \
# 0  Unbox Robotics builds on-demand AI-driven ware...
# 1     UpGrad is an online higher education platform.
# 2  LEAD School offers technology based school tra...
# 3  Bizongo is a business-to-business online marke...
# 4  FypMoney is Digital NEO Bank for Teenagers, em...
#
#                                             Founders  \
# 0                        Pramod Ghadge, Shahid Memon
# 1  Mayank Kumar, Phalgun Kompalli, Ravijot Chugh,...
# 2                         Smita Deorah, Sumeet Mehta
# 3            Aniket Deb, Ankit Tomar, Sachin Agrawal
# 4                                      Kapil Banwari
#
#                                         Investor        Amount         Stage  \
# 0                    BEENEXT, Entrepreneur First    $1,200,000  Pre-series A
# 1       Unilazer Ventures, IIFL Asset Management  $120,000,000           NaN
# 2               GSV Ventures, Westbridge Capital   $30,000,000      Series D
# 3                         CDC Group, IDG Capital   $51,000,000      Series C
# 4  Liberatha Kallat, Mukesh Yadav, Dinesh Nagpal    $2,000,000          Seed
#
#    Year
# 0  2021
# 1  2021
# 2  2021
# 3  2021
# 4  2021

# %%
# Information on df1
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 526 entries, 0 to 525
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company Name   526 non-null    object
#  1   Industry       526 non-null    object
#  2   Round/Series   526 non-null    object
#  3   Amount         526 non-null    object
#  4   Location       526 non-null    object
#  5   About Company  526 non-null    object
#  6   Year           526 non-null    int32
# dtypes: int32(1), object(6)
# memory usage: 26.8+ KB

# %%
# Rename columns in df1 to match columns with similar content in df2, df3 and df4
df1 = df1.rename(columns = {'Company Name' : 'Company_Brand', 'Round/Series' : 'Stage', 'About Company' : 'What_it_does', 'Amount' : 'Amount($)'})

# %%
# Extract Headquarters information from df1's Location column
df1['Headquarters'] = df1['Location'].str.split(',').str[0]
df1['Headquarters']
# Out:
# 0      Bangalore
# 1         Mumbai
# 2        Gurgaon
# 3          Noida
# 4      Hyderabad
#          ...
# 521    Bangalore
# 522      Haryana
# 523       Mumbai
# 524       Mumbai
# 525      Chennai
# Name: Headquarters, Length: 526, dtype: object

# %%
df1['Sector'] = df1['Industry'].str.split(',').str[0]
df1[df1['Sector'] == 'Agritech']
# Out:
# Empty DataFrame
# Columns: [Company_Brand, Industry, Stage, Amount($), Location, What_it_does, Year, Headquarters, Sector]
# Index: []

# %%
# Convert Amount from object to float data type

# First, remove currency symbol ₹
df1['Amount($)'] = df1['Amount($)'].str.replace('₹', '')

# Remove the comma (,) symbol
df1['Amount($)'] = df1['Amount($)'].str.replace(',', '')

# Remove the hyphen (—) symbol
df1['Amount($)'] = df1['Amount($)'].str.replace('—', '')

# Replace all empty spaces with 0
df1['Amount($)'] = df1['Amount($)'].str.replace('', '0')

# Replace all strings longer than 9 character
max_length = 9
df1['Amount($)'] = df1['Amount($)'].apply(lambda x: '0' if len(x) > max_length else x)

# df1['Amount($)'] = df1['Amount($)'].str.replace('0000000$0000000100000004000000030000000100000004000000050000000', '0')

# df1['Amount($)'] = df1['Amount($)'].str.replace('000000000000000$000000000000000100000000000000040000000000000003000000000000000100000000000000040000000000000005000000000000000', '0')

# Remove all white spaces
df1['Amount($)'] = df1['Amount($)'].str.strip()

df1['Amount($)'] = df1['Amount($)'].astype(np.float64).round(2)

# %%
df1.drop(columns = ['Industry', 'Location'])
# Out:
#          Company_Brand     Stage   Amount($)  \
# 0      TheCollegeFever      Seed         0.0
# 1      Happy Cow Dairy      Seed         0.0
# 2           MyLoanCare  Series A         0.0
# 3          PayMe India     Angel         0.0
# 4             Eunimart      Seed         0.0
# ..                 ...       ...         ...
# 521              Udaan  Series C         0.0
# 522  Happyeasygo Group  Series A         0.0
# 523             Mombay      Seed  70500000.0
# 524         Droni Tech      Seed         0.0
# 525            Netmeds  Series C         0.0
#
#                                           What_it_does  Year Headquarters  \
# 0    TheCollegeFever is a hub for fun, fiesta and f...  2018    Bangalore
# 1    A startup which aggregates milk from dairy far...  2018       Mumbai
# 2            Leading Online Loans Marketplace in India  2018      Gurgaon
# 3    PayMe India is an innovative FinTech organizat...  2018        Noida
# 4    Eunimart is a one stop solution for merchants ...  2018    Hyderabad
# ..                                                 ...   ...          ...
# 521  Udaan is a B2B trade platform, designed specif...  2018    Bangalore
# 522            HappyEasyGo is an online travel domain.  2018      Haryana
# 523  Mombay is a unique opportunity for housewives ...  2018       Mumbai
# 524  Droni Tech manufacture UAVs and develop softwa...  2018       Mumbai
# 525       Welcome to India's most convenient pharmacy!  2018      Chennai
#
#                      Sector
# 0           Brand Marketing
# 1               Agriculture
# 2                    Credit
# 3        Financial Services
# 4      E-Commerce Platforms
# ..                      ...
# 521                     B2B
# 522                 Tourism
# 523       Food and Beverage
# 524  Information Technology
# 525           Biotechnology
#
# [526 rows x 7 columns]

# %%
# Checking information on df1 after cleaning the data
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 526 entries, 0 to 525
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  526 non-null    object
#  1   Industry       526 non-null    object
#  2   Stage          526 non-null    object
#  3   Amount($)      526 non-null    float64
#  4   Location       526 non-null    object
#  5   What_it_does   526 non-null    object
#  6   Year           526 non-null    int32
#  7   Headquarters   526 non-null    object
#  8   Sector         526 non-null    object
# dtypes: float64(1), int32(1), object(7)
# memory usage: 35.1+ KB

# %%
df2.Sector
# Out:
# 0                   Ecommerce
# 1                      Edtech
# 2                      Edtech
# 3             Interior design
# 4                    AgriTech
#                ...
# 84                  Infratech
# 85                Hospitality
# 86    Automobile & Technology
# 87                 Automobile
# 88                    Banking
# Name: Sector, Length: 89, dtype: object

# %%
# Checking df2 information before data cleaning
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  89 non-null     object
#  1   Founded        60 non-null     float64
#  2   HeadQuarter    70 non-null     object
#  3   Sector         84 non-null     object
#  4   What it does   89 non-null     object
#  5   Founders       86 non-null     object
#  6   Investor       89 non-null     object
#  7   Amount($)      89 non-null     object
#  8   Stage          43 non-null     object
#  9   Year           89 non-null     int32
# dtypes: float64(1), int32(1), object(8)
# memory usage: 6.7+ KB

# %%
# Fill missing values in Founded column
df2['Founded'] = df2['Founded'].fillna(0)

# %%
# Fill missing values in Founded column
df2['Founded'] = df2['Founded'].fillna(0)

# %%
# Convert Founded column from float to int
df2['Founded'] = df2['Founded'].astype(int)

# %%
# Rename Headquarter to Headquarters
df2 = df2.rename(columns = {'Company/Brand' : 'Company_Brand', 'What it does' : 'What_it_does', 'HeadQuarter' : 'Headquarters'})

# %%
# Convert Amount column from object to float data type

# Remove currency symbol $
df2['Amount($)'] = df2['Amount($)'].str.replace('$', '')

# Remove the comma (,) symbol
df2['Amount($)'] = df2['Amount($)'].str.replace(',', '')

# Replace all strings longer than 9 character
max_length = 9
df2['Amount($)'] = df2['Amount($)'].apply(lambda x: '0' if len(x) > max_length else x)

# Remove all white spaces
df2['Amount($)'] = df2['Amount($)'].str.strip()

df2['Amount($)'] = df2['Amount($)'].astype(np.float64).round(2)

# %%
df2.isna().sum()
# Out:
# Company_Brand     0
# Founded           0
# Headquarters     19
# Sector            5
# What_it_does      0
# Founders          3
# Investor          0
# Amount($)         0
# Stage            46
# Year              0
# dtype: int64

# %%
df2[['Headquarters', 'Sector', 'Founders', 'Stage']] = df2[['Headquarters', 'Sector', 'Founders', 'Stage']].fillna('')

# %%
df2.isna().sum()
# Out:
# Company_Brand    0
# Founded          0
# Headquarters     0
# Sector           0
# What_it_does     0
# Founders         0
# Investor         0
# Amount($)        0
# Stage            0
# Year             0
# dtype: int64

# %%
# Checking df2 after data cleaning
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  89 non-null     object
#  1   Founded        89 non-null     int32
#  2   Headquarters   89 non-null     object
#  3   Sector         89 non-null     object
#  4   What_it_does   89 non-null     object
#  5   Founders       89 non-null     object
#  6   Investor       89 non-null     object
#  7   Amount($)      89 non-null     float64
#  8   Stage          89 non-null     object
#  9   Year           89 non-null     int32
# dtypes: float64(1), int32(2), object(7)
# memory usage: 6.4+ KB

# %%
# df3 information before data cleaning
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1055 entries, 0 to 1054
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  1055 non-null   object
#  1   Founded        842 non-null    float64
#  2   HeadQuarter    961 non-null    object
#  3   Sector         1042 non-null   object
#  4   What_it_does   1055 non-null   object
#  5   Founders       1043 non-null   object
#  6   Investor       1017 non-null   object
#  7   Amount         801 non-null    float64
#  8   Stage          591 non-null    object
#  9   column10       2 non-null      object
#  10  Year           1055 non-null   int32
# dtypes: float64(2), int32(1), object(8)
# memory usage: 86.7+ KB

# %%
# Rename Headquarter to Headquarters
df3 = df3.rename(columns = {'HeadQuarter' : 'Headquarters', 'Amount' : 'Amount($)'})

# %%
df3['Founded'] = df3['Founded'].fillna('0')

# %%
# Convert Founded column from float to int
df3['Founded'] = df3['Founded'].astype(int)

# %%
# # Convert Amount($) column from object to float data type

# # Remove currency symbol $
# df3['Amount($)'] = df3['Amount($)'].str.replace('$', '')

# # Remove the comma (,) symbol
# df3['Amount($)'] = df3['Amount($)'].str.replace(',', '')

# # Replace all strings longer than 9 character
# max_length = 9
# df3['Amount($)'] = df3['Amount($)'].apply(lambda x: '0' if len(x) > max_length else x)

# # Remove all white spaces
# df3['Amount($)'] = df3['Amount($)'].str.strip()

# df3['Amount($)'] = df3['Amount($)'].astype(np.float64).round(2)
df3['Amount($)'].isna().sum()
# Out:
# 254

# %%
df3['Amount($)'] = df3['Amount($)'].fillna(0)

# %%
df3['Stage'].describe()
# Out:
# count          591
# unique          42
# top       Series A
# freq            96
# Name: Stage, dtype: object

# %%
df3.isna().sum()
# Out:
# Company_Brand       0
# Founded             0
# Headquarters       94
# Sector             13
# What_it_does        0
# Founders           12
# Investor           38
# Amount($)           0
# Stage             464
# column10         1053
# Year                0
# dtype: int64

# %%
df3['Stage'] = df3['Stage'].fillna('Unknown')
df3['Stage'].isna().sum()
# Out:
# 0

# %%
df3.tail(20)
# Out:
#          Company_Brand  Founded Headquarters                 Sector  \
# 1035              Byju     2011          NaN                 Edtech
# 1036          Generico        0       Mumbai               Pharmacy
# 1037        HighRadius     2016    Hyderabad                   SaaS
# 1038        Chai Kings        0      Chennai               Beverage
# 1039            Rivigo     2014     Gurugram              Logistics
# 1040          BuildPan     2019       Indore                   SaaS
# 1041           Shiksha     2008          NaN                 Edtech
# 1042    Super Surfaces        0    Hyderabad              Deisgning
# 1043            Quicko        0    Ahmedabad               Taxation
# 1044  Satin Creditcare        0      Gurgaon                Fintech
# 1045        XpressBees     2015          NaN              Logistics
# 1046           FarmERP     2001         Pune               Agritech
# 1047     Wealth Bucket     2018          NaN                Fintech
# 1048        GoMechanic     2016        Delhi  Automobile Technology
# 1049            Fashor     2017      Chennai                Fashion
# 1050      Leverage Edu        0        Delhi                 Edtech
# 1051             EpiFi        0          NaN                Fintech
# 1052           Purplle     2012       Mumbai              Cosmetics
# 1053            Shuttl     2015        Delhi              Transport
# 1054             Pando     2017      Chennai               Logitech
#
#                                            What_it_does  \
# 1035                   Provides online learning classes
# 1036             Generic medicine focussed retail chain
# 1037  An AI-based platform, to automate accounts rec...
# 1038        It offers a range of tea in various flavour
# 1039  It offers delivery services across India to re...
# 1040  It helps developers to test, integrate and dep...
# 1041  It makes college selection easy for students l...
# 1042                    A design solution based company
# 1043            Online tax planning and filing platform
# 1044                            A micro finance company
# 1045         Provides end to end supply chain solutions
# 1046  Smart agriculture management ERP software plat...
# 1047     An online platform for mutual fund investments
# 1048  Find automobile repair and maintenance service...
# 1049                        Women’s fashion and apparel
# 1050  AI enabled marketplace that provides career gu...
# 1051  It offers customers with a single interface fo...
# 1052         Online makeup and beauty products retailer
# 1053                    App based bus aggregator serice
# 1054            Networked logistics management software
#
#                                                Founders  \
# 1035                                    Byju Raveendran
# 1036                                    Siddharth Gadia
# 1037                                     Sashi Narahari
# 1038                  Jahabar Sadique, Balaji Sadagopan
# 1039                           Deepak Garg, Gazal Kalra
# 1040                   Sonal Khandelwal, Vaibhav Tiwari
# 1041                                     Kanav Sachdeva
# 1042                                        Kumar Varma
# 1043                                 Vishvajit Sonagara
# 1044                                                NaN
# 1045                     Supam Maheshwari, Amitava Saha
# 1046                      Santosh Shinde, Sanjay Borkar
# 1047                         Himanshu Jain, Pulkit Jain
# 1048  Amit Bhasin, Kushal Karwa, Nitin Rana, Rishabh...
# 1049                 Vikram Kankaria, Priyanka Kankaria
# 1050                                  Akshay Chaturvedi
# 1051                    Sujith Narayanan, Sumit Gwalani
# 1052                          Manish Taneja, Rahul Dash
# 1053                      Amit Singh, Deepanshu Malviya
# 1054                     Jayakrishnan, Abhijeet Manohar
#
#                                                Investor    Amount($)  \
# 1035                                       Tiger Global  200000000.0
# 1036                                    Alteria Capital    1400000.0
# 1037                                     ICONIQ Capital  125000000.0
# 1038                           The Chennai Angels (TCA)    1000000.0
# 1039                                   Trifecta Capital    3400000.0
# 1040                   HNIs in India, Japan, and the US          0.0
# 1041                              Mumbai Angels Network     181000.0
# 1042                                       Vishnu Reddy     500000.0
# 1043                   Zerodha fintech fund, Rainmatter     280000.0
# 1044                                      Austrian Bank   15000000.0
# 1045                                            Alibaba   10000000.0
# 1046                                          TechnoGen          0.0
# 1047                          NorthStar, Vinod Khatumal    3000000.0
# 1048  Chiratae Ventures, Sequoia Capital, Orios Vent...   14700000.0
# 1049                            Sprout venture partners    1000000.0
# 1050              DSG Consumer Partners, Blume Ventures    1500000.0
# 1051                      Sequoia India, Ribbit Capital   13200000.0
# 1052                                         Verlinvest    8000000.0
# 1053                         SIG Global India Fund LLP.    8043000.0
# 1054                                  Chiratae Ventures    9000000.0
#
#              Stage column10  Year
# 1035       Unknown      NaN  2020
# 1036       Unknown      NaN  2020
# 1037      Series B      NaN  2020
# 1038       Unknown      NaN  2020
# 1039      Series F      NaN  2020
# 1040    Seed Round      NaN  2020
# 1041       Unknown      NaN  2020
# 1042      Series A      NaN  2020
# 1043       Unknown      NaN  2020
# 1044       Unknown      NaN  2020
# 1045       Unknown      NaN  2020
# 1046      Series A      NaN  2020
# 1047       Unknown      NaN  2020
# 1048      Series B      NaN  2020
# 1049  Pre Series A      NaN  2020
# 1050       Unknown      NaN  2020
# 1051    Seed Round      NaN  2020
# 1052       Unknown      NaN  2020
# 1053      Series C      NaN  2020
# 1054      Series A      NaN  2020

# %%
# df3 after renaming column
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1055 entries, 0 to 1054
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  1055 non-null   object
#  1   Founded        1055 non-null   int32
#  2   Headquarters   961 non-null    object
#  3   Sector         1042 non-null   object
#  4   What_it_does   1055 non-null   object
#  5   Founders       1043 non-null   object
#  6   Investor       1017 non-null   object
#  7   Amount($)      1055 non-null   float64
#  8   Stage          1055 non-null   object
#  9   column10       2 non-null      object
#  10  Year           1055 non-null   int32
# dtypes: float64(1), int32(2), object(8)
# memory usage: 82.6+ KB

# %%
# df4 information before data cleaning
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1209 entries, 0 to 1208
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  1209 non-null   object
#  1   Founded        1208 non-null   float64
#  2   HeadQuarter    1208 non-null   object
#  3   Sector         1209 non-null   object
#  4   What_it_does   1209 non-null   object
#  5   Founders       1205 non-null   object
#  6   Investor       1147 non-null   object
#  7   Amount         1206 non-null   object
#  8   Stage          781 non-null    object
#  9   Year           1209 non-null   int32
# dtypes: float64(1), int32(1), object(8)
# memory usage: 89.9+ KB

# %%
# Rename Headquarter to Headquarters
df4 = df4.rename(columns = {'HeadQuarter' : 'Headquarters', 'Amount' : 'Amount($)'})

# %%
df4['Founded'] = df4['Founded'].fillna(0)

# %%
# Convert Founded column from float to int
df4['Founded'] = df4['Founded'].astype(int)

# %%
df4['Stage'] = df4['Stage'].fillna('')

# %%
# Convert Amount($) column from object to float data type

# Remove currency symbol $
df4['Amount($)'] = df4['Amount($)'].str.replace('$', '')
df4['Stage'] = df4['Stage'].str.replace('$', '')
df4['Stage'] = df4['Stage'].str.replace(',', '')
df4['Investor'] = df4['Investor'].str.replace('$', '')
df4['Investor'] = df4['Investor'].str.replace(',', '')
df4['Investor'] = df4['Investor'].str.strip()

# %%
# Define a function to check if a string represents an integer
def is_string_integer(s):
    try:
        int(s)
        return True
    except ValueError:
        return False

# Apply the function to the 'Stage' column to create a boolean mask
condition = df4['Stage'].apply(is_string_integer)

# Swap values between 'Stage' and 'Amount($)' columns where condition is True
temp = df4.loc[condition, 'Stage'].copy()
df4.loc[condition, 'Stage'] = df4.loc[condition, 'Amount($)']
df4.loc[condition, 'Amount($)'] = temp



# df4[['Amount($)', 'Stage']]
df4
# Out:
#        Company_Brand  Founded Headquarters                 Sector  \
# 0     Unbox Robotics     2019    Bangalore             AI startup
# 1             upGrad     2015       Mumbai                 EdTech
# 2        Lead School     2012       Mumbai                 EdTech
# 3            Bizongo     2015       Mumbai         B2B E-commerce
# 4           FypMoney     2021     Gurugram                FinTech
# ...              ...      ...          ...                    ...
# 1204        Gigforce     2019     Gurugram  Staffing & Recruiting
# 1205          Vahdam     2015    New Delhi       Food & Beverages
# 1206    Leap Finance     2019    Bangalore     Financial Services
# 1207    CollegeDekho     2015     Gurugram                 EdTech
# 1208          WeRize     2019    Bangalore     Financial Services
#
#                                            What_it_does  \
# 0     Unbox Robotics builds on-demand AI-driven ware...
# 1        UpGrad is an online higher education platform.
# 2     LEAD School offers technology based school tra...
# 3     Bizongo is a business-to-business online marke...
# 4     FypMoney is Digital NEO Bank for Teenagers, em...
# ...                                                 ...
# 1204                  A gig/on-demand staffing company.
# 1205  VAHDAM is among the world’s first vertically i...
# 1206  International education loans for high potenti...
# 1207  Collegedekho.com is Student’s Partner, Friend ...
# 1208  India’s first socially distributed full stack ...
#
#                                                Founders  \
# 0                           Pramod Ghadge, Shahid Memon
# 1     Mayank Kumar, Phalgun Kompalli, Ravijot Chugh,...
# 2                            Smita Deorah, Sumeet Mehta
# 3               Aniket Deb, Ankit Tomar, Sachin Agrawal
# 4                                         Kapil Banwari
# ...                                                 ...
# 1204                        Chirag Mittal, Anirudh Syal
# 1205                                         Bala Sarda
# 1206                         Arnav Kumar, Vaibhav Singh
# 1207                                       Ruchir Arora
# 1208                      Vishal Chopra, Himanshu Gupta
#
#                                          Investor    Amount($)         Stage  \
# 0                      BEENEXT Entrepreneur First    1,200,000  Pre-series A
# 1         Unilazer Ventures IIFL Asset Management  120,000,000
# 2                 GSV Ventures Westbridge Capital   30,000,000      Series D
# 3                           CDC Group IDG Capital   51,000,000      Series C
# 4     Liberatha Kallat Mukesh Yadav Dinesh Nagpal    2,000,000          Seed
# ...                                           ...          ...           ...
# 1204                              Endiya Partners      3000000  Pre-series A
# 1205                                     IIFL AMC     20000000      Series D
# 1206                                 Owl Ventures     55000000      Series C
# 1207               Winter Capital ETS Man Capital     26000000      Series B
# 1208                3one4 Capital Kalaari Capital      8000000      Series A
#
#       Year
# 0     2021
# 1     2021
# 2     2021
# 3     2021
# 4     2021
# ...    ...
# 1204  2021
# 1205  2021
# 1206  2021
# 1207  2021
# 1208  2021
#
# [1209 rows x 10 columns]

# %%
df4.groupby(by = 'Amount($)', as_index = False).sum()
# Out:
#          Amount($)                                      Company_Brand  \
# 0                                                        EventBeepMPL
# 1        1,000,000  TaikeeFuel BuddyLearnVernmoEVingSolethreadsWiT...
# 2    1,000,000,000                                   VerSe Innovation
# 3        1,100,000                              Jambox GamesDusMinute
# 4        1,200,000                                     Unbox Robotics
# ..             ...                                                ...
# 268   Pre-series A                                          AdmitKard
# 269           Seed                                   MoEVingGodamwale
# 270       Series C               Fullife HealthcareFullife Healthcare
# 271    Undisclosed  Qube HealthVitra.aiUableTruNativAntWakRage Cof...
# 272    undisclosed  Learn4o TechnologyKeerosSuperBeingsHyreoGODI E...
#
#      Founded                                       Headquarters  \
# 0       4037                                      PuneBangalore
# 1      66576  MumbaiNew DelhiAhmadabadGurugramGurugramGurugr...
# 2       2007                                          Bangalore
# 3       4038                                 BangaloreBangalore
# 4       2019                                          Bangalore
# ..       ...                                                ...
# 268     2016                                              Noida
# 269     4037                              Gurugram\t#REF!Mumbai
# 270     4018       Pharmaceuticals\t#REF!Pharmaceuticals\t#REF!
# 271   234051  MumbaiBangaloreBangaloreMumbaiBangaloreNew Del...
# 272    44395  JaipurLucknowBangaloreThiruvananthapuramHydera...
#
#                                                 Sector  \
# 0                                         EdTechsports
# 1    E-commerceOil and EnergyEdTechLogisticsFashion...
# 2                                Innovation Management
# 3                                         GamingRetail
# 4                                           AI startup
# ..                                                 ...
# 268                                             EdTech
# 269  MoEVing is India's only Electric Mobility focu...
# 270  Primary Business is Development and Manufactur...
# 271  HealthTechTech StartupEdTechFood & BeveragesEd...
# 272  E-learningFood & BeveragesComputer softwareHum...
#
#                                           What_it_does  \
# 0    An inclusive community where students are insp...
# 1    Taikee is the ISO-certified, B2B e-commerce pl...
# 2                     Owner of Dailyhunt App and I-Pay
# 3    A competitive game publishing platform to help...
# 4    Unbox Robotics builds on-demand AI-driven ware...
# ..                                                 ...
# 268  A tech solution for end to end career advisory...
# 269  Vikash Mishra, Mragank JainGodamwale is tech e...
# 270                           Varun KhannaVarun Khanna
# 271  India's Most Respected Workplace Healthcare Ma...
# 272  Trying to solve the problem of unemployment in...
#
#                                               Founders  \
# 0    Saurabh Mangrulkar, Rakhi Pal, Venkatesh Prasa...
# 1    Nidhi Ramachandran, Sachin ChhabraAditya Singh...
# 2                                       Virendra Gupta
# 3                              Ravi VyasApoorva Mishra
# 4                          Pramod Ghadge, Shahid Memon
# ..                                                 ...
# 268   Vamsi Krishna, Pulkit Jain, Gaurav Munjal\t#REF!
# 269  Anshuman Maheshwary, Dr Srihari Raju Kalidindi...
# 270  Morgan Stanley Private Equity AsiaMorgan Stanl...
# 271  Gagan KapurAkash Nidhi PSSaurabh SaxenaPranav ...
# 272  Kamal Kant GuptaSachin Sahni, Simran SahniYash...
#
#                                               Investor  \
# 0    SucSEED  Indovation Fund Uincept Palimala Vent...
# 1    Jaipuria Family OfficeDSG Consumer Partners Sa...
# 2    Canaan Valley Capital Glade Brook Capital Part...
# 3                                 Indian Angel Network
# 4                           BEENEXT Entrepreneur First
# ..                                                 ...
# 268                                            1000000
# 269                              50000001000000\t#REF!
# 270                                   2200000022000000
# 271  Inflection Point VenturesInflexor VenturesChir...
# 272  IANVenture CatalystsEndiya PartnersCallapina C...
#
#                                                  Stage    Year
# 0                                             Series E    4042
# 1    SeedSeries ASeedPre-series ASeedSeedSeedDebtDe...   66693
# 2                                             Series H    2021
# 3                                     SeedPre-series A    4042
# 4                                         Pre-series A    2021
# ..                                                 ...     ...
# 268                                                       2021
# 269                                                       4042
# 270                                                       4042
# 271  Pre-series ASeedSeedSeedPre-series APre-series...  234436
# 272  SeedPre-series ASeedPre-series ASeedSeedSeedSe...   44462
#
# [273 rows x 10 columns]

# %%
df4['Amount($)'].isna().sum()
# Out:
# 2

# %%
df4['Amount($)'] = df4['Amount($)'].fillna('0')

# %%
# Define the pattern you want to search for in the 'Amount($)' column
pattern = 'Series'  # Replace 'pattern' with your desired pattern

# Identify rows where the 'Amount($)' column contains the specified pattern
condition = df4['Amount($)'].str.contains(pattern)

# Move the values from 'Amount($)' to 'Stage' where the pattern is found
df4.loc[condition, 'Stage'] = df4.loc[condition, 'Amount($)']

# Replace the values in 'Amount($)' with NaN where the pattern is found
df4.loc[condition, 'Amount($)'] = pd.NA

df4.groupby(by = 'Amount($)', as_index = False).sum()
# Out:
#          Amount($)                                      Company_Brand  \
# 0                                                        EventBeepMPL
# 1                0                                   OnsuritySochcast
# 2        1,000,000  TaikeeFuel BuddyLearnVernmoEVingSolethreadsWiT...
# 3    1,000,000,000                                   VerSe Innovation
# 4        1,100,000                              Jambox GamesDusMinute
# ..             ...                                                ...
# 268       96000000                                       Pristyn Care
# 269   Pre-series A                                          AdmitKard
# 270           Seed                                   MoEVingGodamwale
# 271    Undisclosed  Qube HealthVitra.aiUableTruNativAntWakRage Cof...
# 272    undisclosed  Learn4o TechnologyKeerosSuperBeingsHyreoGODI E...
#
#      Founded                                       Headquarters  \
# 0       4037                                      PuneBangalore
# 1       4040                       BangaloreOnline Media\t#REF!
# 2      66576  MumbaiNew DelhiAhmadabadGurugramGurugramGurugr...
# 3       2007                                          Bangalore
# 4       4038                                 BangaloreBangalore
# ..       ...                                                ...
# 268     2018                                           Gurugram
# 269     2016                                              Noida
# 270     4037                              Gurugram\t#REF!Mumbai
# 271   234051  MumbaiBangaloreBangaloreMumbaiBangaloreNew Del...
# 272    44395  JaipurLucknowBangaloreThiruvananthapuramHydera...
#
#                                                 Sector  \
# 0                                         EdTechsports
# 1    HealthCareSochcast is an Audio experiences com...
# 2    E-commerceOil and EnergyEdTechLogisticsFashion...
# 3                                Innovation Management
# 4                                         GamingRetail
# ..                                                 ...
# 268                             Hospital & Health Care
# 269                                             EdTech
# 270  MoEVing is India's only Electric Mobility focu...
# 271  HealthTechTech StartupEdTechFood & BeveragesEd...
# 272  E-learningFood & BeveragesComputer softwareHum...
#
#                                           What_it_does  \
# 0    An inclusive community where students are insp...
# 1    Onsurity is an employee healthcare platform pr...
# 2    Taikee is the ISO-certified, B2B e-commerce pl...
# 3                     Owner of Dailyhunt App and I-Pay
# 4    A competitive game publishing platform to help...
# ..                                                 ...
# 268  A new age health tech company that aims to sim...
# 269  A tech solution for end to end career advisory...
# 270  Vikash Mishra, Mragank JainGodamwale is tech e...
# 271  India's Most Respected Workplace Healthcare Ma...
# 272  Trying to solve the problem of unemployment in...
#
#                                               Founders  \
# 0    Saurabh Mangrulkar, Rakhi Pal, Venkatesh Prasa...
# 1    Kulin Shah, Yogesh AgarwalVinners, Raj Nayak, ...
# 2    Nidhi Ramachandran, Sachin ChhabraAditya Singh...
# 3                                       Virendra Gupta
# 4                              Ravi VyasApoorva Mishra
# ..                                                 ...
# 268  Harsimarbir (Harsh) Singh, Dr Vaibhav Kapoor, ...
# 269   Vamsi Krishna, Pulkit Jain, Gaurav Munjal\t#REF!
# 270  Anshuman Maheshwary, Dr Srihari Raju Kalidindi...
# 271  Gagan KapurAkash Nidhi PSSaurabh SaxenaPranav ...
# 272  Kamal Kant GuptaSachin Sahni, Simran SahniYash...
#
#                                               Investor  \
# 0    SucSEED  Indovation Fund Uincept Palimala Vent...
# 1                 Jitendra Gupta Harsh ShahUndisclosed
# 2    Jaipuria Family OfficeDSG Consumer Partners Sa...
# 3    Canaan Valley Capital Glade Brook Capital Part...
# 4                                 Indian Angel Network
# ..                                                 ...
# 268      Kunal Shah Deepinder Goyal Abhiraj Singh Bhal
# 269                                            1000000
# 270                              50000001000000\t#REF!
# 271  Inflection Point VenturesInflexor VenturesChir...
# 272  IANVenture CatalystsEndiya PartnersCallapina C...
#
#                                                  Stage    Year
# 0                                             Series E    4042
# 1                                                         4042
# 2    SeedSeries ASeedPre-series ASeedSeedSeedDebtDe...   66693
# 3                                             Series H    2021
# 4                                     SeedPre-series A    4042
# ..                                                 ...     ...
# 268                                           Series E    2021
# 269                                                       2021
# 270                                                       4042
# 271  Pre-series ASeedSeedSeedPre-series APre-series...  234436
# 272  SeedPre-series ASeedPre-series ASeedSeedSeedSe...   44462
#
# [273 rows x 10 columns]

# %%
df4['Amount($)'] = df4['Amount($)'].fillna('0')

# %%
# Define the pattern you want to search for in the 'Amount($)' column
pattern = 'Seed'  # Replace 'pattern' with your desired pattern

# Identify rows where the 'Amount($)' column contains the specified pattern
condition = df4['Amount($)'].str.contains(pattern)

# Move the values from 'Amount($)' to 'Stage' where the pattern is found
df4.loc[condition, 'Stage'] = df4.loc[condition, 'Amount($)']

# Replace the values in 'Amount($)' with NaN where the pattern is found
df4.loc[condition, 'Amount($)'] = pd.NA

df4.groupby(by = 'Amount($)', as_index = False).sum()
# Out:
#          Amount($)                                      Company_Brand  \
# 0                                                        EventBeepMPL
# 1                0  OnsurityFullife HealthcareFullife HealthcareSo...
# 2        1,000,000  TaikeeFuel BuddyLearnVernmoEVingSolethreadsWiT...
# 3    1,000,000,000                                   VerSe Innovation
# 4        1,100,000                              Jambox GamesDusMinute
# ..             ...                                                ...
# 267        9500000                                     SkepsByteLearn
# 268       96000000                                       Pristyn Care
# 269   Pre-series A                                          AdmitKard
# 270    Undisclosed  Qube HealthVitra.aiUableTruNativAntWakRage Cof...
# 271    undisclosed  Learn4o TechnologyKeerosSuperBeingsHyreoGODI E...
#
#      Founded                                       Headquarters  \
# 0       4037                                      PuneBangalore
# 1       8058  BangalorePharmaceuticals\t#REF!Pharmaceuticals...
# 2      66576  MumbaiNew DelhiAhmadabadGurugramGurugramGurugr...
# 3       2007                                          Bangalore
# 4       4038                                 BangaloreBangalore
# ..       ...                                                ...
# 267     4039                                      GurugramNoida
# 268     2018                                           Gurugram
# 269     2016                                              Noida
# 270   234051  MumbaiBangaloreBangaloreMumbaiBangaloreNew Del...
# 271    44395  JaipurLucknowBangaloreThiruvananthapuramHydera...
#
#                                                 Sector  \
# 0                                         EdTechsports
# 1    HealthCarePrimary Business is Development and ...
# 2    E-commerceOil and EnergyEdTechLogisticsFashion...
# 3                                Innovation Management
# 4                                         GamingRetail
# ..                                                 ...
# 267                                  FinTechE-learning
# 268                             Hospital & Health Care
# 269                                             EdTech
# 270  HealthTechTech StartupEdTechFood & BeveragesEd...
# 271  E-learningFood & BeveragesComputer softwareHum...
#
#                                           What_it_does  \
# 0    An inclusive community where students are insp...
# 1    Onsurity is an employee healthcare platform pr...
# 2    Taikee is the ISO-certified, B2B e-commerce pl...
# 3                     Owner of Dailyhunt App and I-Pay
# 4    A competitive game publishing platform to help...
# ..                                                 ...
# 267  A blockchain products company, developing a pr...
# 268  A new age health tech company that aims to sim...
# 269  A tech solution for end to end career advisory...
# 270  India's Most Respected Workplace Healthcare Ma...
# 271  Trying to solve the problem of unemployment in...
#
#                                               Founders  \
# 0    Saurabh Mangrulkar, Rakhi Pal, Venkatesh Prasa...
# 1    Kulin Shah, Yogesh AgarwalMorgan Stanley Priva...
# 2    Nidhi Ramachandran, Sachin ChhabraAditya Singh...
# 3                                       Virendra Gupta
# 4                              Ravi VyasApoorva Mishra
# ..                                                 ...
# 267                   Mayank Tewari, Tushar Srivastava
# 268  Harsimarbir (Harsh) Singh, Dr Vaibhav Kapoor, ...
# 269   Vamsi Krishna, Pulkit Jain, Gaurav Munjal\t#REF!
# 270  Gagan KapurAkash Nidhi PSSaurabh SaxenaPranav ...
# 271  Kamal Kant GuptaSachin Sahni, Simran SahniYash...
#
#                                               Investor  \
# 0    SucSEED  Indovation Fund Uincept Palimala Vent...
# 1    Jitendra Gupta Harsh Shah2200000022000000Undis...
# 2    Jaipuria Family OfficeDSG Consumer Partners Sa...
# 3    Canaan Valley Capital Glade Brook Capital Part...
# 4                                 Indian Angel Network
# ..                                                 ...
# 267      Bertelsmann IndiaAditya Singhal Nishant Sinha
# 268      Kunal Shah Deepinder Goyal Abhiraj Singh Bhal
# 269                                            1000000
# 270  Inflection Point VenturesInflexor VenturesChir...
# 271  IANVenture CatalystsEndiya PartnersCallapina C...
#
#                                                  Stage    Year
# 0                                             Series E    4042
# 1                                     Series CSeries C    8084
# 2    SeedSeries ASeedPre-series ASeedSeedSeedDebtDe...   66693
# 3                                             Series H    2021
# 4                                     SeedPre-series A    4042
# ..                                                 ...     ...
# 267                                               Seed    4042
# 268                                           Series E    2021
# 269                                                       2021
# 270  Pre-series ASeedSeedSeedPre-series APre-series...  234436
# 271  SeedPre-series ASeedPre-series ASeedSeedSeedSe...   44462
#
# [272 rows x 10 columns]

# %%
df4['Amount($)'] = df4['Amount($)'].fillna('0')

# %%
# Define the pattern you want to search for in the 'Amount($)' column
pattern = 'Pre-s'  # Replace 'pattern' with your desired pattern

# Identify rows where the 'Amount($)' column contains the specified pattern
condition = df4['Amount($)'].str.contains(pattern)

# Move the values from 'Amount($)' to 'Stage' where the pattern is found
df4.loc[condition, 'Stage'] = df4.loc[condition, 'Amount($)']

# Replace the values in 'Amount($)' with NaN where the pattern is found
df4.loc[condition, 'Amount($)'] = pd.NA

df4.groupby(by = 'Amount($)', as_index = False).sum()
# Out:
#          Amount($)                                      Company_Brand  \
# 0                                                        EventBeepMPL
# 1                0  OnsurityFullife HealthcareFullife HealthcareMo...
# 2        1,000,000  TaikeeFuel BuddyLearnVernmoEVingSolethreadsWiT...
# 3    1,000,000,000                                   VerSe Innovation
# 4        1,100,000                              Jambox GamesDusMinute
# ..             ...                                                ...
# 266     95,000,000                                        MPLLenskart
# 267        9500000                                     SkepsByteLearn
# 268       96000000                                       Pristyn Care
# 269    Undisclosed  Qube HealthVitra.aiUableTruNativAntWakRage Cof...
# 270    undisclosed  Learn4o TechnologyKeerosSuperBeingsHyreoGODI E...
#
#      Founded                                       Headquarters  \
# 0       4037                                      PuneBangalore
# 1      12095  BangalorePharmaceuticals\t#REF!Pharmaceuticals...
# 2      66576  MumbaiNew DelhiAhmadabadGurugramGurugramGurugr...
# 3       2007                                          Bangalore
# 4       4038                                 BangaloreBangalore
# ..       ...                                                ...
# 266     4028                        BangaloreFaridabad, Haryana
# 267     4039                                      GurugramNoida
# 268     2018                                           Gurugram
# 269   234051  MumbaiBangaloreBangaloreMumbaiBangaloreNew Del...
# 270    44395  JaipurLucknowBangaloreThiruvananthapuramHydera...
#
#                                                 Sector  \
# 0                                         EdTechsports
# 1    HealthCarePrimary Business is Development and ...
# 2    E-commerceOil and EnergyEdTechLogisticsFashion...
# 3                                Innovation Management
# 4                                         GamingRetail
# ..                                                 ...
# 266                                      GamingFashion
# 267                                  FinTechE-learning
# 268                             Hospital & Health Care
# 269  HealthTechTech StartupEdTechFood & BeveragesEd...
# 270  E-learningFood & BeveragesComputer softwareHum...
#
#                                           What_it_does  \
# 0    An inclusive community where students are insp...
# 1    Onsurity is an employee healthcare platform pr...
# 2    Taikee is the ISO-certified, B2B e-commerce pl...
# 3                     Owner of Dailyhunt App and I-Pay
# 4    A competitive game publishing platform to help...
# ..                                                 ...
# 266  Mobile Premier League is a skill-based eSports...
# 267  A blockchain products company, developing a pr...
# 268  A new age health tech company that aims to sim...
# 269  India's Most Respected Workplace Healthcare Ma...
# 270  Trying to solve the problem of unemployment in...
#
#                                               Founders  \
# 0    Saurabh Mangrulkar, Rakhi Pal, Venkatesh Prasa...
# 1    Kulin Shah, Yogesh AgarwalMorgan Stanley Priva...
# 2    Nidhi Ramachandran, Sachin ChhabraAditya Singh...
# 3                                       Virendra Gupta
# 4                              Ravi VyasApoorva Mishra
# ..                                                 ...
# 266  Sai Srinivas Kiran G, Shubham MalhotraAmit Cha...
# 267                   Mayank Tewari, Tushar Srivastava
# 268  Harsimarbir (Harsh) Singh, Dr Vaibhav Kapoor, ...
# 269  Gagan KapurAkash Nidhi PSSaurabh SaxenaPranav ...
# 270  Kamal Kant GuptaSachin Sahni, Simran SahniYash...
#
#                                               Investor  \
# 0    SucSEED  Indovation Fund Uincept Palimala Vent...
# 1    Jitendra Gupta Harsh Shah220000002200000050000...
# 2    Jaipuria Family OfficeDSG Consumer Partners Sa...
# 3    Canaan Valley Capital Glade Brook Capital Part...
# 4                                 Indian Angel Network
# ..                                                 ...
# 266  Pegasus Tech Ventures Base PartnersKohlberg Kr...
# 267      Bertelsmann IndiaAditya Singhal Nishant Sinha
# 268      Kunal Shah Deepinder Goyal Abhiraj Singh Bhal
# 269  Inflection Point VenturesInflexor VenturesChir...
# 270  IANVenture CatalystsEndiya PartnersCallapina C...
#
#                                                  Stage    Year
# 0                                             Series E    4042
# 1                             Series CSeries CSeedSeed   12126
# 2    SeedSeries ASeedPre-series ASeedSeedSeedDebtDe...   66693
# 3                                             Series H    2021
# 4                                     SeedPre-series A    4042
# ..                                                 ...     ...
# 266                                                       4042
# 267                                               Seed    4042
# 268                                           Series E    2021
# 269  Pre-series ASeedSeedSeedPre-series APre-series...  234436
# 270  SeedPre-series ASeedPre-series ASeedSeedSeedSe...   44462
#
# [271 rows x 10 columns]

# %%
df4.groupby(by = 'Investor', as_index = False).sum()
# Out:
#                                               Investor        Company_Brand  \
# 0                          021 Capital Sparrow Capital               Wasabi
# 1                             021 Capital Y Combinator            Fountain9
# 2                                              1000000            AdmitKard
# 3                                       1000000\t#REF!            Godamwale
# 4    100X.VC﻿﻿ Titan Capital Rahul Mathur Gaurav Ma...            BlueLearn
# ..                                                 ...                  ...
# 932                                    http://100x.vc/             Karnival
# 933                                iSeed Titan Capital               BimaPe
# 934                                        pi Ventures  Insane AIimmunitoAI
# 935            responsAbility Investments Blue Orchard   SATYA MicroCapital
# 936                                        velocity.in           Green Soul
#
#      Founded        Headquarters                    Sector  \
# 0       2021           Bangalore                Consulting
# 1       2019              Mumbai         Computer software
# 2       2016               Noida                    EdTech
# 3       2016              Mumbai  Logistics & Supply Chain
# 4       2020                 Goa                    EdTech
# ..       ...                 ...                       ...
# 932     2015           Bangalore              SaaS startup
# 933     2020              Mumbai                   FinTech
# 934     4041  BangaloreBangalore      FitnessBiotechnology
# 935     2017           New Delhi                   Banking
# 936     2016           Ambernath            Consumer Goods
#
#                                           What_it_does  \
# 0    Help small businesses grow their sales via our...
# 1    Fountain9 is a Y Combinator backed company, wh...
# 2    A tech solution for end to end career advisory...
# 3    Godamwale is tech enabled integrated logistics...
# 4    Building India's largest student community. Le...
# ..                                                 ...
# 932  A SAAS platform for retailers and brands to cr...
# 933  BimaPe demystifies Insurance and its Managemen...
# 934  Mainstream fitness formats are a primitive sol...
# 935  Satya MicroCapital Limited is a Delhi based NB...
# 936  Green Soul is No.1 brand on Amazon India in Er...
#
#                                               Founders      Amount($)  \
# 0                         Pradeep Dodle, Nikhil Goenka        1800000
# 1                           Niki Khokale, Rajas Lonkar        1900000
# 2     Vamsi Krishna, Pulkit Jain, Gaurav Munjal\t#REF!              0
# 3            Basant Kumar, Vivek Tiwari, Ranbir Nandan              0
# 4                Harish Uthayakumar, Shreyans Sancheti         400000
# ..                                                 ...            ...
# 932                                       Neeraj Tyagi      2,500,000
# 933                                       Rahul Mathur         500000
# 934  Anurag Mundhada, Jayesh Hannurkar, Sourabh Agr...  8000001000000
# 935                                       Vivek Tiwari       10000000
# 936                                     Ravi Khushwani         200000
#
#             Stage  Year
# 0            Seed  2021
# 1            Seed  2021
# 2    Pre-series A  2021
# 3            Seed  2021
# 4        Pre-seed  2021
# ..            ...   ...
# 932          Seed  2021
# 933      Pre-seed  2021
# 934      SeedSeed  4042
# 935                2021
# 936                2021
#
# [937 rows x 10 columns]

# %%
df4['Investor'] = df4['Investor'].fillna('')

# %%
# Identify rows where 'Investor' column contains '$' symbol
condition = df4['Investor'].str.contains('1000000')

# Move values with '$' symbol from 'Investor' to 'Amount($)' column
df4.loc[condition, 'Amount($)'] = df4.loc[condition, 'Investor']

# Remove the '$' symbol from the 'Amount($)' column
df4['Amount($)'] = df4['Amount($)'].str.replace('$', '')

# Replace remaining values in 'Investor' with NaN
# df4.loc[condition, 'Investor'] = pd.NA

# print(df)

# %%
# Identify rows where 'Investor' column contains '$' symbol
condition = df4['Investor'].str.contains('5000000')

# Move values with '$' symbol from 'Investor' to 'Amount($)' column
df4.loc[condition, 'Amount($)'] = df4.loc[condition, 'Investor']

# Remove the '$' symbol from the 'Amount($)' column
df4['Amount($)'] = df4['Amount($)'].str.replace('$', '')

# Replace remaining values in 'Investor' with NaN
# df4.loc[condition, 'Investor'] = pd.NA

# print(df)

# %%
# Identify rows where 'Investor' column contains '$' symbol
condition = df4['Investor'].str.contains('1000000')

# Move values with '$' symbol from 'Investor' to 'Amount($)' column
df4.loc[condition, 'Amount($)'] = df4.loc[condition, 'Investor']

# Remove the '$' symbol from the 'Amount($)' column
df4['Amount($)'] = df4['Amount($)'].str.replace('$', '')

# Replace remaining values in 'Investor' with NaN
# df4.loc[condition, 'Investor'] = pd.NA

# print(df)

# %%
# Identify rows where 'Investor' column contains '$' symbol
condition = df4['Investor'].str.contains('22000000')

# Move values with '$' symbol from 'Investor' to 'Amount($)' column
df4.loc[condition, 'Amount($)'] = df4.loc[condition, 'Investor']

# Remove the '$' symbol from the 'Amount($)' column
df4['Amount($)'] = df4['Amount($)'].str.replace('$', '')
df4['Investor'] = df4['Investor'].str.replace('1000000', 'NA')
df4['Investor'] = df4['Investor'].str.replace('1000000\t#REF!', 'NA')
# Replace remaining values in 'Investor' with NaN
# df4.loc[condition, 'Investor'] = pd.NA

# print(df)

# %%
df4.groupby(by = 'Investor', as_index = False).sum()
# Out:
#                                               Investor  \
# 0
# 1                          021 Capital Sparrow Capital
# 2                             021 Capital Y Combinator
# 3    100X.VC﻿﻿ Titan Capital Rahul Mathur Gaurav Ma...
# 4                                   100x Entrepreneurs
# ..                                                 ...
# 933                                    http://100x.vc/
# 934                                iSeed Titan Capital
# 935                                        pi Ventures
# 936            responsAbility Investments Blue Orchard
# 937                                        velocity.in
#
#                                          Company_Brand  Founded  \
# 0    TaikeeJambox GamesLearnVernmoEVingWeWork India...   125020
# 1                                               Wasabi     2021
# 2                                            Fountain9     2019
# 3                                            BlueLearn     2020
# 4                                           Slang Labs     2017
# ..                                                 ...      ...
# 933                                           Karnival     2015
# 934                                             BimaPe     2020
# 935                                Insane AIimmunitoAI     4041
# 936                                 SATYA MicroCapital     2017
# 937                                         Green Soul     2016
#
#                                           Headquarters  \
# 0    MumbaiBangaloreAhmadabadGurugramBangaloreMumba...
# 1                                            Bangalore
# 2                                               Mumbai
# 3                                                  Goa
# 4                                            Bangalore
# ..                                                 ...
# 933                                          Bangalore
# 934                                             Mumbai
# 935                                 BangaloreBangalore
# 936                                          New Delhi
# 937                                          Ambernath
#
#                                                 Sector  \
# 0    E-commerceGamingEdTechLogisticsHospitalityFinT...
# 1                                           Consulting
# 2                                    Computer software
# 3                                               EdTech
# 4                                    Computer software
# ..                                                 ...
# 933                                       SaaS startup
# 934                                            FinTech
# 935                               FitnessBiotechnology
# 936                                            Banking
# 937                                     Consumer Goods
#
#                                           What_it_does  \
# 0    Taikee is the ISO-certified, B2B e-commerce pl...
# 1    Help small businesses grow their sales via our...
# 2    Fountain9 is a Y Combinator backed company, wh...
# 3    Building India's largest student community. Le...
# 4    Slang Labs provides accurate and multilingual ...
# ..                                                 ...
# 933  A SAAS platform for retailers and brands to cr...
# 934  BimaPe demystifies Insurance and its Managemen...
# 935  Mainstream fitness formats are a primitive sol...
# 936  Satya MicroCapital Limited is a Delhi based NB...
# 937  Green Soul is No.1 brand on Amazon India in Er...
#
#                                               Founders  \
# 0    Nidhi Ramachandran, Sachin ChhabraRavi VyasNir...
# 1                         Pradeep Dodle, Nikhil Goenka
# 2                           Niki Khokale, Rajas Lonkar
# 3                Harish Uthayakumar, Shreyans Sancheti
# 4                                     Kumar Rangarajan
# ..                                                 ...
# 933                                       Neeraj Tyagi
# 934                                       Rahul Mathur
# 935  Anurag Mundhada, Jayesh Hannurkar, Sourabh Agr...
# 936                                       Vivek Tiwari
# 937                                     Ravi Khushwani
#
#                                              Amount($)  \
# 0    1,000,0001,100,0001,000,0001,000,00026,000,000...
# 1                                              1800000
# 2                                              1900000
# 3                                               400000
# 4                                          undisclosed
# ..                                                 ...
# 933                                          2,500,000
# 934                                             500000
# 935                                      8000001000000
# 936                                           10000000
# 937                                             200000
#
#                                                  Stage    Year
# 0    SeedSeedDebtPre-series ASeries EPre-series APr...  125302
# 1                                                 Seed    2021
# 2                                                 Seed    2021
# 3                                             Pre-seed    2021
# 4                                                         2021
# ..                                                 ...     ...
# 933                                               Seed    2021
# 934                                           Pre-seed    2021
# 935                                           SeedSeed    4042
# 936                                                       2021
# 937                                                       2021
#
# [938 rows x 10 columns]

# %%
df4.Investor.isna().sum()
# Out:
# 0

# %%
df4.describe().T
# Out:
#           count         mean        std     min     25%     50%     75%  \
# Founded  1209.0  2014.987593  58.174256     0.0  2015.0  2018.0  2020.0
# Year     1209.0  2021.000000   0.000000  2021.0  2021.0  2021.0  2021.0
#
#             max
# Founded  2021.0
# Year     2021.0

# %%
# Convert Amount column from object to float data type

# Remove currency symbol $
df4['Amount($)'] = df4['Amount($)'].str.replace('$', '')

# Remove the comma (,) symbol
df4['Amount($)'] = df4['Amount($)'].str.replace(',', '')
df4['Amount($)'] = df4['Amount($)'].str.replace('', '0')
# Replace all strings longer than 9 character
max_length = 9
df4['Amount($)'] = df4['Amount($)'].apply(lambda x: '0' if len(x) > max_length else x)

# Remove all white spaces
df4['Amount($)'] = df4['Amount($)'].str.strip()

df4['Amount($)'] = df4['Amount($)'].astype(np.float64).round(2)

# %%
df4.isna().sum()
# Out:
# Company_Brand    0
# Founded          0
# Headquarters     1
# Sector           0
# What_it_does     0
# Founders         4
# Investor         0
# Amount($)        0
# Stage            1
# Year             0
# dtype: int64

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1209 entries, 0 to 1208
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  1209 non-null   object
#  1   Founded        1209 non-null   int32
#  2   Headquarters   1208 non-null   object
#  3   Sector         1209 non-null   object
#  4   What_it_does   1209 non-null   object
#  5   Founders       1205 non-null   object
#  6   Investor       1209 non-null   object
#  7   Amount($)      1209 non-null   float64
#  8   Stage          1208 non-null   object
#  9   Year           1209 non-null   int32
# dtypes: float64(1), int32(2), object(7)
# memory usage: 85.1+ KB

# %%
# Concatenate all DataFrames along rows
df = pd.concat([df1, df2, df3, df4], ignore_index=True)

# If there are overlapping columns, you can handle them separately if needed

# Print the concatenated DataFrame
df
# Out:
#         Company_Brand                                           Industry  \
# 0     TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1     Happy Cow Dairy                               Agriculture, Farming
# 2          MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3         PayMe India                        Financial Services, FinTech
# 4            Eunimart                 E-Commerce Platforms, Retail, SaaS
# ...               ...                                                ...
# 2874         Gigforce                                                NaN
# 2875           Vahdam                                                NaN
# 2876     Leap Finance                                                NaN
# 2877     CollegeDekho                                                NaN
# 2878           WeRize                                                NaN
#
#              Stage  Amount($)                          Location  \
# 0             Seed        0.0       Bangalore, Karnataka, India
# 1             Seed        0.0        Mumbai, Maharashtra, India
# 2         Series A        0.0           Gurgaon, Haryana, India
# 3            Angel        0.0       Noida, Uttar Pradesh, India
# 4             Seed        0.0  Hyderabad, Andhra Pradesh, India
# ...            ...        ...                               ...
# 2874  Pre-series A        0.0                               NaN
# 2875      Series D        0.0                               NaN
# 2876      Series C        0.0                               NaN
# 2877      Series B        0.0                               NaN
# 2878      Series A        0.0                               NaN
#
#                                            What_it_does  Year Headquarters  \
# 0     TheCollegeFever is a hub for fun, fiesta and f...  2018    Bangalore
# 1     A startup which aggregates milk from dairy far...  2018       Mumbai
# 2             Leading Online Loans Marketplace in India  2018      Gurgaon
# 3     PayMe India is an innovative FinTech organizat...  2018        Noida
# 4     Eunimart is a one stop solution for merchants ...  2018    Hyderabad
# ...                                                 ...   ...          ...
# 2874                  A gig/on-demand staffing company.  2021     Gurugram
# 2875  VAHDAM is among the world’s first vertically i...  2021    New Delhi
# 2876  International education loans for high potenti...  2021    Bangalore
# 2877  Collegedekho.com is Student’s Partner, Friend ...  2021     Gurugram
# 2878  India’s first socially distributed full stack ...  2021    Bangalore
#
#                      Sector  Founded                       Founders  \
# 0           Brand Marketing      NaN                            NaN
# 1               Agriculture      NaN                            NaN
# 2                    Credit      NaN                            NaN
# 3        Financial Services      NaN                            NaN
# 4      E-Commerce Platforms      NaN                            NaN
# ...                     ...      ...                            ...
# 2874  Staffing & Recruiting   2019.0    Chirag Mittal, Anirudh Syal
# 2875       Food & Beverages   2015.0                     Bala Sarda
# 2876     Financial Services   2019.0     Arnav Kumar, Vaibhav Singh
# 2877                 EdTech   2015.0                   Ruchir Arora
# 2878     Financial Services   2019.0  Vishal Chopra, Himanshu Gupta
#
#                             Investor column10
# 0                                NaN      NaN
# 1                                NaN      NaN
# 2                                NaN      NaN
# 3                                NaN      NaN
# 4                                NaN      NaN
# ...                              ...      ...
# 2874                 Endiya Partners      NaN
# 2875                        IIFL AMC      NaN
# 2876                    Owl Ventures      NaN
# 2877  Winter Capital ETS Man Capital      NaN
# 2878   3one4 Capital Kalaari Capital      NaN
#
# [2879 rows x 13 columns]

# %%
df.drop(columns=['column10'], inplace=True)
df
# Out:
#         Company_Brand                                           Industry  \
# 0     TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1     Happy Cow Dairy                               Agriculture, Farming
# 2          MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3         PayMe India                        Financial Services, FinTech
# 4            Eunimart                 E-Commerce Platforms, Retail, SaaS
# ...               ...                                                ...
# 2874         Gigforce                                                NaN
# 2875           Vahdam                                                NaN
# 2876     Leap Finance                                                NaN
# 2877     CollegeDekho                                                NaN
# 2878           WeRize                                                NaN
#
#              Stage  Amount($)                          Location  \
# 0             Seed        0.0       Bangalore, Karnataka, India
# 1             Seed        0.0        Mumbai, Maharashtra, India
# 2         Series A        0.0           Gurgaon, Haryana, India
# 3            Angel        0.0       Noida, Uttar Pradesh, India
# 4             Seed        0.0  Hyderabad, Andhra Pradesh, India
# ...            ...        ...                               ...
# 2874  Pre-series A        0.0                               NaN
# 2875      Series D        0.0                               NaN
# 2876      Series C        0.0                               NaN
# 2877      Series B        0.0                               NaN
# 2878      Series A        0.0                               NaN
#
#                                            What_it_does  Year Headquarters  \
# 0     TheCollegeFever is a hub for fun, fiesta and f...  2018    Bangalore
# 1     A startup which aggregates milk from dairy far...  2018       Mumbai
# 2             Leading Online Loans Marketplace in India  2018      Gurgaon
# 3     PayMe India is an innovative FinTech organizat...  2018        Noida
# 4     Eunimart is a one stop solution for merchants ...  2018    Hyderabad
# ...                                                 ...   ...          ...
# 2874                  A gig/on-demand staffing company.  2021     Gurugram
# 2875  VAHDAM is among the world’s first vertically i...  2021    New Delhi
# 2876  International education loans for high potenti...  2021    Bangalore
# 2877  Collegedekho.com is Student’s Partner, Friend ...  2021     Gurugram
# 2878  India’s first socially distributed full stack ...  2021    Bangalore
#
#                      Sector  Founded                       Founders  \
# 0           Brand Marketing      NaN                            NaN
# 1               Agriculture      NaN                            NaN
# 2                    Credit      NaN                            NaN
# 3        Financial Services      NaN                            NaN
# 4      E-Commerce Platforms      NaN                            NaN
# ...                     ...      ...                            ...
# 2874  Staffing & Recruiting   2019.0    Chirag Mittal, Anirudh Syal
# 2875       Food & Beverages   2015.0                     Bala Sarda
# 2876     Financial Services   2019.0     Arnav Kumar, Vaibhav Singh
# 2877                 EdTech   2015.0                   Ruchir Arora
# 2878     Financial Services   2019.0  Vishal Chopra, Himanshu Gupta
#
#                             Investor
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ...                              ...
# 2874                 Endiya Partners
# 2875                        IIFL AMC
# 2876                    Owl Ventures
# 2877  Winter Capital ETS Man Capital
# 2878   3one4 Capital Kalaari Capital
#
# [2879 rows x 12 columns]

# %%
df.describe().T.round(2)
# Out:
#             count         mean           std     min     25%     50%  \
# Amount($)  2879.0  32634370.20  1.306852e+09     0.0     0.0     0.0
# Year       2879.0      2020.02  1.090000e+00  2018.0  2020.0  2020.0
# Founded    2353.0      1807.87  6.136700e+02     0.0  2013.0  2016.0
#
#                 75%           max
# Amount($)  600000.0  7.000000e+10
# Year         2021.0  2.021000e+03
# Founded      2019.0  2.021000e+03

# %%
df.isna().sum()
# Out:
# Company_Brand       0
# Industry         2353
# Stage               1
# Amount($)           0
# Location         2353
# What_it_does        0
# Year                0
# Headquarters       95
# Sector             13
# Founded           526
# Founders          542
# Investor          564
# dtype: int64

# %%
df['Amount($)'].mean().round(2)
# Out:
# 32634370.2

# %%
df.head()
# Out:
#      Company_Brand                                           Industry  \
# 0  TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1  Happy Cow Dairy                               Agriculture, Farming
# 2       MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3      PayMe India                        Financial Services, FinTech
# 4         Eunimart                 E-Commerce Platforms, Retail, SaaS
#
#       Stage  Amount($)                          Location  \
# 0      Seed        0.0       Bangalore, Karnataka, India
# 1      Seed        0.0        Mumbai, Maharashtra, India
# 2  Series A        0.0           Gurgaon, Haryana, India
# 3     Angel        0.0       Noida, Uttar Pradesh, India
# 4      Seed        0.0  Hyderabad, Andhra Pradesh, India
#
#                                         What_it_does  Year Headquarters  \
# 0  TheCollegeFever is a hub for fun, fiesta and f...  2018    Bangalore
# 1  A startup which aggregates milk from dairy far...  2018       Mumbai
# 2          Leading Online Loans Marketplace in India  2018      Gurgaon
# 3  PayMe India is an innovative FinTech organizat...  2018        Noida
# 4  Eunimart is a one stop solution for merchants ...  2018    Hyderabad
#
#                  Sector  Founded Founders Investor
# 0       Brand Marketing      NaN      NaN      NaN
# 1           Agriculture      NaN      NaN      NaN
# 2                Credit      NaN      NaN      NaN
# 3    Financial Services      NaN      NaN      NaN
# 4  E-Commerce Platforms      NaN      NaN      NaN

# %%
df.shape
# Out:
# (2879, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2879 entries, 0 to 2878
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  2879 non-null   object
#  1   Industry       526 non-null    object
#  2   Stage          2878 non-null   object
#  3   Amount($)      2879 non-null   float64
#  4   Location       526 non-null    object
#  5   What_it_does   2879 non-null   object
#  6   Year           2879 non-null   int32
#  7   Headquarters   2784 non-null   object
#  8   Sector         2866 non-null   object
#  9   Founded        2353 non-null   float64
#  10  Founders       2337 non-null   object
#  11  Investor       2315 non-null   object
# dtypes: float64(2), int32(1), object(9)
# memory usage: 258.8+ KB

# %%
df.describe()
# Out:
#           Amount($)         Year      Founded
# count  2.879000e+03  2879.000000  2353.000000
# mean   3.263437e+07  2020.023619  1807.874203
# std    1.306852e+09     1.086974   613.666318
# min    0.000000e+00  2018.000000     0.000000
# 25%    0.000000e+00  2020.000000  2013.000000
# 50%    0.000000e+00  2020.000000  2016.000000
# 75%    6.000000e+05  2021.000000  2019.000000
# max    7.000000e+10  2021.000000  2021.000000

# %%
# df.duplicated().sum()

# %%
# df.drop_duplicates()

# %% [markdown]
# ### Visualizing Characteristics of the Dataset

# %%
# Visualize the distribution of the start-ups' Stage with boxplot
df.plot.box(column='Amount($)', by='Year')
# Out:
# Amount($)    Axes(0.125,0.11;0.775x0.77)
# dtype: object

# %%
# Visualize the distribution of the start-ups' Location with boxplot
df.plot.box(column='Amount($)', by='Founded')
# Out:
# Amount($)    Axes(0.125,0.11;0.775x0.77)
# dtype: object

# %%
# Distribution of the variables
df.hist(figsize=(20, 15))
# Out:
# array([[<Axes: title={'center': 'Amount($)'}>,
#         <Axes: title={'center': 'Year'}>],
#        [<Axes: title={'center': 'Founded'}>, <Axes: >]], dtype=object)
